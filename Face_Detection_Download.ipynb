# %%
import os

# %%
# !kaggle datasets download -d jessicali9530/celeba-dataset --path ./celeba
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jessicali9530/celeba-dataset
# License(s): other
# ...
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
#   9%|8         | 117M/1.33G [00:00<00:01, 1.22GB/s]
#  17%|#7        | 234M/1.33G [00:00<00:01, 1.15GB/s]
#  29%|##8       | 394M/1.33G [00:00<00:00, 1.38GB/s]
#  39%|###8      | 527M/1.33G [00:00<00:00, 1.04GB/s]
#  47%|####6     | 636M/1.33G [00:00<00:00, 931MB/s]
#  54%|#####3    | 732M/1.33G [00:00<00:00, 812MB/s]
#  60%|#####9    | 815M/1.33G [00:00<00:00, 711MB/s]
#  66%|######5   | 892M/1.33G [00:01<00:00, 721MB/s]
#  72%|#######2  | 982M/1.33G [00:01<00:00, 740MB/s]
#  79%|#######8  | 1.05G/1.33G [00:01<00:00, 757MB/s]
#  84%|########4 | 1.12G/1.33G [00:01<00:00, 757MB/s]
#  90%|########9 | 1.19G/1.33G [00:01<00:00, 662MB/s]
#  95%|#########5| 1.27G/1.33G [00:01<00:00, 664MB/s]
# 100%|##########| 1.33G/1.33G [00:01<00:00, 804MB/s]

# %%
# !unzip -q ./celeba/celeba-dataset.zip -d ./celeba

# %% [markdown]
# #### LFW

# %%
# !kaggle datasets download -d jessicali9530/lfw-dataset --path ./lfw
# !unzip -q ./lfw/lfw-dataset.zip -d ./lfw

# %% [markdown]
# #### UTKFace

# %%
# !kaggle datasets download -d jangedoo/utkface-new --path ./utkface
# !unzip -q ./utkface/utkface-new.zip -d ./utkface

# %% [markdown]
# #### FFHW

# %%
# !kaggle datasets download -d arnaud58/flickrfaceshq-dataset-ffhq --path ./ffhq
# !unzip -q ./ffhq/flickrfaceshq-dataset-ffhq.zip -d ./ffhq

# %%
import psutil
ram = psutil.virtual_memory()
print(f"Total RAM:     {ram.total / 1e9:.1f} GB")
print(f"Available RAM: {ram.available / 1e9:.1f} GB")
print(f"Used RAM:      {ram.used / 1e9:.1f} GB")
# Out:
# Total RAM:     16.9 GB
# Available RAM: 3.4 GB
# Used RAM:      13.5 GB

# %%
print(f"Available RAM: {psutil.virtual_memory().available / 1e9:.1f} GB")
# Out:
# Available RAM: 3.2 GB
